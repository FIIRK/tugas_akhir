# %%
from PIL import Image
from scripts.pipe import pipeline

model = pipeline("model1_weights.pth", "model2_weights.pth")

# %%
image_pre  = Image.open("sample_data/images/pre/joplin-tornado_00000000.png")
image_post = Image.open("sample_data/images/post/joplin-tornado_00000000.png")

model.predict(image_pre, image_post)

# %%
model.result.mask
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>

# %%
model.result.dmgs
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
